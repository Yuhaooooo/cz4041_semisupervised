# %% [markdown]
# ## --------------------------
# ## Get data
# ## --------------------------

# %%
import pandas as pd
import numpy as np
import seaborn as sns

processedDataStorePath = '../processed_data/'

# %%
X_train_labeled = np.load(processedDataStorePath+'X_train_labeled.npy')
y_train_labeled = np.load(processedDataStorePath+'y_train_labeled.npy')
X_train_unlabeled = np.load(processedDataStorePath+'X_train_unlabeled.npy')
y_train_unlabeled = np.load(processedDataStorePath+'y_train_unlabeled.npy')
X_test = np.load(processedDataStorePath+'X_test.npy')
y_test = np.load(processedDataStorePath+'y_test.npy')

# %%
unique, counts = np.unique(y_train_labeled, return_counts=True)
print('for train labeled data: \n', np.asarray((unique, counts)).T) 

unique, counts = np.unique(y_train_unlabeled, return_counts=True)
print('for train unlabeled data: \n', np.asarray((unique, counts)).T) 

unique, counts = np.unique(y_test, return_counts=True)
print('for test data: \n', np.asarray((unique, counts)).T)
# Out:
# for train labeled data:
#  [[  0 274]
#  [  1 205]]
# for train unlabeled data:
#  [['unlabeled' 4288]]
# for test data:
#  [[  0 292]
#  [  1 237]]

# %%
def drawDf(x1,x2,label,df):
    sns.lmplot(x1, x2, data=df, fit_reg=False,  # x-axis, y-axis, data, no line
                   scatter_kws={"s": 100}, # marker size
                   palette='Set1',
                   hue=label)
    
def drawNpArray(x1,x2,y):
    df = pd.DataFrame({'x1':x1,'x2':x2,'label':y})
    drawDf('x1','x2','label',df)
    
print('\nall train labeled data distribution graph: ')
drawNpArray(X_train_labeled.T[0],X_train_labeled.T[1],y_train_labeled)

print('\nall test data distribution graph: ')
drawNpArray(X_test.T[0],X_test.T[1],y_test)
# Out:
# all train labeled data distribution graph:
#
# all test data distribution graph:

# %%
part = 160 # how many data needed for training
randomSeed = random.randint(1,100)
print('randomSeed: ',randomSeed)

# random.Random(randomSeed).shuffle(X_train_labeled)
X_part_train_labeled = X_train_labeled[:part]
# random.Random(randomSeed).shuffle(y_train_labeled)
y_part_train_labeled = y_train_labeled[:part]

unique, counts = np.unique(y_part_train_labeled, return_counts=True)
print('for train unlabeled data: \n', np.asarray((unique, counts)).T)
# Out:
# randomSeed:  27
# for train unlabeled data:
#  [[ 0 92]
#  [ 1 68]]

# %%
# a=[[1],[2],[3],[4]]
# b=[1,2,3,4]
# random.Random(40).shuffle(a)
# random.Random(40).shuffle(b)
# print(a)
# print(b)
# Out:
# [[2], [1], [3], [4]]
# [2, 1, 3, 4]

# %% [markdown]
# ## --------------------------
# ## Testing
# ## --------------------------

# %%
import random
from sklearn.model_selection import train_test_split

# randomList = [random.randint(1,100) for i in range(2)]

X_train, X_val, y_train, y_val = train_test_split(X_part_train_labeled,y_part_train_labeled, test_size=0.5, random_state=42)

# X_train, X_val, y_train, y_val = train_test_split(X_train_labeled,y_train_labeled, test_size=0.5, random_state=42)

print('train: ', len(y_train), ' val: ',len(y_val), ' test: ', len(y_test))

drawNpArray(X_train.T[0],X_train.T[1],y_train)
drawNpArray(X_val.T[0],X_val.T[1],y_val)
drawNpArray(X_test.T[0],X_test.T[1],y_test)
# Out:
# train:  80  val:  80  test:  529

# %%
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix  
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import random

def testXGBoost(X_train,y_train,X_val,y_val,X_test,y_test):
    
    dtrain = xgb.DMatrix(data = X_train, label = y_train)
    Dval = xgb.DMatrix(data=X_val, label=y_val)
    Dtest = xgb.DMatrix(data = X_test, label = y_test)
    
#     drawNpArray(X_train.T[0],X_train.T[1],y_train)

    param = {'max_depth': 3, 'eta': 1, 'silent': 1, 'objective': 'binary:logistic','estimators':500,'eval_metric':'auc'}

    evallist = [(Dval, 'eval')]
    plst = param.items()

    num_round = 500

    bst = xgb.train(plst, dtrain, num_round, evallist, early_stopping_rounds=10, verbose_eval=50)
    y_pred_score = bst.predict(Dtest)
    y_pred = [round(value) for value in y_pred_score]

    print(confusion_matrix(y_test,y_pred),'\n')
    print(accuracy_score(y_test,y_pred),'\n')
    
    return bst,accuracy_score(y_test,y_pred)

# %%
bst,acc=testXGBoost(X_train,y_train,X_val,y_val,X_test,y_test)
# Out:
# [0]	eval-auc:0.798322
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	eval-auc:0.952402
#
# [[243  49]
#  [ 46 191]]
#
# 0.8204158790170132

# %%
import heapq

# return all with same highest confidence
def getIndexWithHighConfidence(data,p):
    print('=========================================')
    print('=========================================')
    largestList=[]
    smallestList=[]
    largestValue = heapq.nlargest(1,data)[0]
    print('largest value: ', largestValue)
    smallestValue = heapq.nsmallest(1,data)[0]
    print('smallest value: ', smallestValue)
    if largestValue>.7:
        largestList = [idx for idx, val in enumerate(data) if abs(val-largestValue)<=p]
        if (len(largestList)>20):
            random.shuffle(largestList)
            largestList=largestList[:20]
        print('len of largest list: ', len(largestList))
    if smallestValue<.3:
        smallestList = [idx for idx, val in enumerate(data) if abs(val-smallestValue)<=p]
        if (len(smallestList)>20):
            random.shuffle(smallestList)
            smallestList=smallestList[:20]
        print('len of smallest list: ', len(smallestList))
    indexList = largestList + smallestList

    print('=========================================')
    print('=========================================')
    
    indexList.sort()
    indexList.reverse()
#     print(indexList)

    return indexList

# def getIndexWithHighConfidence(data):

#     largestValues = heapq.nlargest(1, data)
#     print('largest value: ', largestValues)
#     smallestValus = heapq.nsmallest(1, data)
#     print('smallest value: ', smallestValus)
    
#     print('=========================================')
#     print('=========================================')
#     print('=========================================')

#     largestList = [idx for idx, val in enumerate(data) if val in largestValues]
#     print('largest list: ', largestList)
#     if (len(largestList)>10):
#         random.shuffle(largestList)
#         largestList=largestList[:10]
#     print('largest list: ', largestList)
    
#     print('=========================================')
#     print('=========================================')
#     print('=========================================')
    
#     smallestList = [idx for idx, val in enumerate(data) if val in smallestValus]
#     print('smallest list: ', smallestList)
#     if (len(smallestList)>10):
#         random.shuffle(smallestList)
#         smallestList=smallestList[:10]
#     print('smallest list: ', smallestList)

#     indexList = largestList + smallestList

#     indexList.sort()
#     indexList.reverse()
#     print('=========================================')
#     print('=========================================')
#     print('=========================================')
#     print(indexList)

#     return indexList

# %%
# create a copy for testing purpose
# X_trainval_1 = 
# X_unlabeled_1=X_unlabeled[:]
# y_unlabeled_1=y_unlabeled[:]

# %%
prob = 0.004
a=getIndexWithHighConfidence(bst.predict(xgb.DMatrix(data=X_train_unlabeled, label=[1 for i in y_train_unlabeled])),prob)
# Out:
# =========================================
# =========================================
# largest value:  0.9981346
# smallest value:  0.0007917273
# len of largest list:  316
# len of smallest list:  159
# =========================================
# =========================================

# %%
bst,acc=testXGBoost(X_train,y_train,X_val,y_val,X_test,y_test)
# Out:
# [0]	eval-auc:0.798322
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	eval-auc:0.952402
#
# [[243  49]
#  [ 46 191]]
#
# 0.8204158790170132

# %%
X_train_labeled = np.load(processedDataStorePath+'X_train_labeled.npy')
y_train_labeled = np.load(processedDataStorePath+'y_train_labeled.npy')
X_train_unlabeled = np.load(processedDataStorePath+'X_train_unlabeled.npy')
y_train_unlabeled = np.load(processedDataStorePath+'y_train_unlabeled.npy')
X_test = np.load(processedDataStorePath+'X_test.npy')
y_test = np.load(processedDataStorePath+'y_test.npy')

part=240
start=40
X_part_train_labeled = X_train_labeled[start:part+start]
y_part_train_labeled = y_train_labeled[start:part+start]
# X_part_train_labeled = X_train_labeled[part:]
# y_part_train_labeled = y_train_labeled[part:]

X_train, X_val, y_train, y_val = train_test_split(X_part_train_labeled,y_part_train_labeled, test_size=0.5, random_state=42)

# %%
# bst=testXGBoost(X_train,y_train,X_val,y_val,X_test,y_test)

accuracy=[]
prob = 0.002

bst,acc = testXGBoost(X_train,y_train,X_val,y_val,X_test,y_test)
accuracy.append(acc)

for i in range(100):
    y_pseudo_score = bst.predict(xgb.DMatrix(data=X_train_unlabeled, label=[1 for i in y_train_unlabeled]))
    y_pseudo = np.array(list(map(int,[np.round(i) for i in y_pseudo_score])))
    
    X_new=[]
    y_new=[]

    for index in getIndexWithHighConfidence(y_pseudo_score,prob):
        X_new.append(X_train_unlabeled[index])
        y_new.append(y_pseudo[index])
        X_train_unlabeled=np.delete(X_train_unlabeled,index,0) # 0 is row
        y_train_unlabeled=np.delete(y_train_unlabeled,index)

    X_new=np.array(X_new)
    y_new=np.array(y_new)
    print('number of newly added: ',len(y_new))

    X_train = np.concatenate((X_train,X_new),axis=0)
    y_train = np.concatenate((y_train,y_new),axis=0)
    
    if i%10==0:
        prob=prob*1.5
        
    if i%20==0:
        drawNpArray(X_train.T[0],X_train.T[1],y_train)

    bst,acc = testXGBoost(X_train,y_train,X_val,y_val,X_test,y_test)
    accuracy.append(acc)
# Out:
# [0]	eval-auc:0.741714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	eval-auc:0.905286
#
# [[254  38]
#  [ 49 188]]
#
# 0.8355387523629489
#
# =========================================
# =========================================
# largest value:  0.99580646
# smallest value:  0.00022150508
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.799571
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	eval-auc:0.923143
#
# [[258  34]
#  [ 58 179]]
#
# 0.8260869565217391
#
# =========================================
# =========================================
# largest value:  0.9966355
# smallest value:  4.8680173e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.799857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	eval-auc:0.923714
#
# [[259  33]
#  [ 55 182]]
#
# 0.833648393194707
#
# =========================================
# =========================================
# largest value:  0.998423
# smallest value:  0.00027006172
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.799857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [22]	eval-auc:0.909714
#
# [[257  35]
#  [ 58 179]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.99933124
# smallest value:  9.025517e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	eval-auc:0.918143
#
# [[255  37]
#  [ 58 179]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.9987361
# smallest value:  0.00018086849
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	eval-auc:0.918429
#
# [[262  30]
#  [ 57 180]]
#
# 0.8355387523629489
#
# =========================================
# =========================================
# largest value:  0.9997229
# smallest value:  9.3835064e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	eval-auc:0.921714
#
# [[257  35]
#  [ 62 175]]
#
# 0.8166351606805293
#
# =========================================
# =========================================
# largest value:  0.9996704
# smallest value:  4.0071714e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	eval-auc:0.921429
#
# [[254  38]
#  [ 54 183]]
#
# 0.8260869565217391
#
# =========================================
# =========================================
# largest value:  0.99961686
# smallest value:  4.5880493e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [23]	eval-auc:0.922143
#
# [[256  36]
#  [ 59 178]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.9999167
# smallest value:  3.82838e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.919429
#
# [[252  40]
#  [ 51 186]]
#
# 0.8279773156899811
#
# =========================================
# =========================================
# largest value:  0.9997068
# smallest value:  5.3223077e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	eval-auc:0.919
#
# [[254  38]
#  [ 53 184]]
#
# 0.8279773156899811
#
# =========================================
# =========================================
# largest value:  0.99938464
# smallest value:  7.639274e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	eval-auc:0.919
#
# [[254  38]
#  [ 55 182]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.99941015
# smallest value:  7.364799e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.922143
#
# [[255  37]
#  [ 54 183]]
#
# 0.8279773156899811
#
# =========================================
# =========================================
# largest value:  0.9993724
# smallest value:  8.1316604e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	eval-auc:0.922571
#
# [[255  37]
#  [ 51 186]]
#
# 0.833648393194707
#
# =========================================
# =========================================
# largest value:  0.9994974
# smallest value:  5.3938096e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	eval-auc:0.926571
#
# [[256  36]
#  [ 53 184]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.9998535
# smallest value:  5.8116813e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.757429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	eval-auc:0.927286
#
# [[256  36]
#  [ 52 185]]
#
# 0.833648393194707
#
# =========================================
# =========================================
# largest value:  0.9998153
# smallest value:  8.476698e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.923857
#
# [[256  36]
#  [ 49 188]]
#
# 0.8393194706994329
#
# =========================================
# =========================================
# largest value:  0.9997485
# smallest value:  7.520531e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	eval-auc:0.927
# [[253  39]
#  [ 52 185]]
#
# 0.8279773156899811
#
# =========================================
# =========================================
# largest value:  0.99976116
# smallest value:  3.0516167e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [19]	eval-auc:0.924429
#
# [[254  38]
#  [ 51 186]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.9998945
# smallest value:  5.183765e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	eval-auc:0.918286
#
# [[257  35]
#  [ 54 183]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.99965906
# smallest value:  8.813803e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	eval-auc:0.918857
#
# [[256  36]
#  [ 58 179]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.9995233
# smallest value:  0.00013493074
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [36]	eval-auc:0.918571
#
# [[260  32]
#  [ 59 178]]
#
# 0.8279773156899811
#
# =========================================
# =========================================
# largest value:  0.999941
# smallest value:  2.8694607e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.914714
#
# [[256  36]
#  [ 51 186]]
#
# 0.8355387523629489
#
# =========================================
# =========================================
# largest value:  0.9996462
# smallest value:  5.886086e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	eval-auc:0.917571
#
# [[255  37]
#  [ 50 187]]
#
# 0.8355387523629489
#
# =========================================
# =========================================
# largest value:  0.9996393
# smallest value:  7.8733974e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	eval-auc:0.915571
#
# [[257  35]
#  [ 51 186]]
#
# 0.8374291115311909
#
# =========================================
# =========================================
# largest value:  0.9995622
# smallest value:  2.5569489e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.921286
#
# [[257  35]
#  [ 48 189]]
#
# 0.8431001890359168
#
# =========================================
# =========================================
# largest value:  0.9997484
# smallest value:  2.1893653e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	eval-auc:0.921
#
# [[256  36]
#  [ 53 184]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.99979454
# smallest value:  3.361865e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	eval-auc:0.925429
#
# [[255  37]
#  [ 51 186]]
#
# 0.833648393194707
#
# =========================================
# =========================================
# largest value:  0.9996731
# smallest value:  3.9180915e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	eval-auc:0.922571
#
# [[255  37]
#  [ 53 184]]
#
# 0.8298676748582231
#
# =========================================
# =========================================
# largest value:  0.9997869
# smallest value:  2.502308e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	eval-auc:0.924143
#
# [[257  35]
#  [ 53 184]]
#
# 0.833648393194707
#
# =========================================
# =========================================
# largest value:  0.9996891
# smallest value:  4.9250913e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	eval-auc:0.927143
#
# [[257  35]
#  [ 53 184]]
#
# 0.833648393194707
#
# =========================================
# =========================================
# largest value:  0.9996101
# smallest value:  4.08494e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.772857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [3]	eval-auc:0.914857
#
# [[257  35]
#  [ 54 183]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.99958724
# smallest value:  8.058381e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	eval-auc:0.917857
#
# [[255  37]
#  [ 56 181]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.99955577
# smallest value:  0.00011639951
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	eval-auc:0.918429
#
# [[256  36]
#  [ 54 183]]
#
# 0.8298676748582231
#
# =========================================
# =========================================
# largest value:  0.99983096
# smallest value:  2.320223e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	eval-auc:0.914
#
# [[255  37]
#  [ 52 185]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.9999355
# smallest value:  1.9406945e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	eval-auc:0.915714
#
# [[256  36]
#  [ 53 184]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.9997954
# smallest value:  1.783209e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	eval-auc:0.922143
#
# [[255  37]
#  [ 58 179]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.99990463
# smallest value:  2.615086e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	eval-auc:0.915429
#
# [[257  35]
#  [ 53 184]]
#
# 0.833648393194707
#
# =========================================
# =========================================
# largest value:  0.9999325
# smallest value:  1.3474799e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.917857
#
# [[254  38]
#  [ 54 183]]
#
# 0.8260869565217391
#
# =========================================
# =========================================
# largest value:  0.999881
# smallest value:  1.7077646e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	eval-auc:0.923571
#
# [[253  39]
#  [ 43 194]]
#
# 0.8449905482041588
#
# =========================================
# =========================================
# largest value:  0.99978465
# smallest value:  2.314868e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773714
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	eval-auc:0.917571
#
# [[248  44]
#  [ 55 182]]
#
# 0.8128544423440454
#
# =========================================
# =========================================
# largest value:  0.99992466
# smallest value:  7.042296e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	eval-auc:0.909286
#
# [[256  36]
#  [ 58 179]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.99987817
# smallest value:  1.1762726e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.908857
#
# [[257  35]
#  [ 51 186]]
#
# 0.8374291115311909
#
# =========================================
# =========================================
# largest value:  0.99992764
# smallest value:  2.944734e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	eval-auc:0.910143
#
# [[260  32]
#  [ 57 180]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.999913
# smallest value:  1.7139482e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	eval-auc:0.909286
#
# [[255  37]
#  [ 53 184]]
#
# 0.8298676748582231
#
# =========================================
# =========================================
# largest value:  0.9998247
# smallest value:  2.3458224e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	eval-auc:0.911
#
# [[255  37]
#  [ 52 185]]
#
# 0.831758034026465
#
# =========================================
# =========================================
# largest value:  0.9998442
# smallest value:  1.7927714e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.778429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [19]	eval-auc:0.91
#
# [[255  37]
#  [ 54 183]]
#
# 0.8279773156899811
#
# =========================================
# =========================================
# largest value:  0.9999573
# smallest value:  7.5825765e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [25]	eval-auc:0.913429
#
# [[248  44]
#  [ 55 182]]
#
# 0.8128544423440454
#
# =========================================
# =========================================
# largest value:  0.9999045
# smallest value:  2.8288036e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	eval-auc:0.916714
#
# [[250  42]
#  [ 53 184]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.9999217
# smallest value:  3.990972e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	eval-auc:0.914571
#
# [[250  42]
#  [ 53 184]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.99977726
# smallest value:  7.564404e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.777286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	eval-auc:0.915143
#
# [[248  44]
#  [ 49 188]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.99957615
# smallest value:  9.11033e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.795143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [20]	eval-auc:0.913286
#
# [[249  43]
#  [ 54 183]]
#
# 0.8166351606805293
#
# =========================================
# =========================================
# largest value:  0.9998024
# smallest value:  1.8151835e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.795143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [20]	eval-auc:0.912143
#
# [[247  45]
#  [ 56 181]]
#
# 0.8090737240075614
#
# =========================================
# =========================================
# largest value:  0.9997693
# smallest value:  4.5602346e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.813143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	eval-auc:0.910429
#
# [[247  45]
#  [ 55 182]]
#
# 0.8109640831758034
#
# =========================================
# =========================================
# largest value:  0.999539
# smallest value:  1.5572848e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.813143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	eval-auc:0.914286
#
# [[243  49]
#  [ 56 181]]
#
# 0.8015122873345936
#
# =========================================
# =========================================
# largest value:  0.9997993
# smallest value:  7.714855e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.813143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [21]	eval-auc:0.919571
#
# [[244  48]
#  [ 54 183]]
#
# 0.8071833648393195
#
# =========================================
# =========================================
# largest value:  0.99959725
# smallest value:  4.8734164e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.813143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [25]	eval-auc:0.914143
#
# [[245  47]
#  [ 54 183]]
#
# 0.8090737240075614
#
# =========================================
# =========================================
# largest value:  0.9996449
# smallest value:  4.5040932e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.797286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	eval-auc:0.921714
#
# [[248  44]
#  [ 51 186]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.99947554
# smallest value:  7.557979e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.811
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [28]	eval-auc:0.917286
#
# [[244  48]
#  [ 51 186]]
#
# 0.8128544423440454
#
# =========================================
# =========================================
# largest value:  0.99911326
# smallest value:  2.281106e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.811857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	eval-auc:0.917286
#
# [[245  47]
#  [ 53 184]]
#
# 0.8109640831758034
#
# =========================================
# =========================================
# largest value:  0.99874914
# smallest value:  3.2702214e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.811857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [34]	eval-auc:0.908571
#
# [[246  46]
#  [ 51 186]]
#
# 0.8166351606805293
#
# =========================================
# =========================================
# largest value:  0.99982244
# smallest value:  5.8904664e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.811857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [28]	eval-auc:0.907
#
# [[241  51]
#  [ 50 187]]
#
# 0.8090737240075614
#
# =========================================
# =========================================
# largest value:  0.9986921
# smallest value:  4.5624913e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.811857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [24]	eval-auc:0.921429
#
# [[247  45]
#  [ 50 187]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.99878496
# smallest value:  1.06428956e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.821571
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	eval-auc:0.924143
#
# [[238  54]
#  [ 52 185]]
#
# 0.7996219281663516
#
# =========================================
# =========================================
# largest value:  0.9989753
# smallest value:  6.8370496e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.821571
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	eval-auc:0.922571
#
# [[238  54]
#  [ 52 185]]
#
# 0.7996219281663516
#
# =========================================
# =========================================
# largest value:  0.99908364
# smallest value:  5.3096574e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.825
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [27]	eval-auc:0.925571
#
# [[244  48]
#  [ 53 184]]
#
# 0.8090737240075614
#
# =========================================
# =========================================
# largest value:  0.9994338
# smallest value:  6.4049885e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.767
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	eval-auc:0.925143
#
# [[249  43]
#  [ 53 184]]
#
# 0.8185255198487713
#
# =========================================
# =========================================
# largest value:  0.99918634
# smallest value:  2.330565e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.767
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [33]	eval-auc:0.908714
#
# [[241  51]
#  [ 50 187]]
#
# 0.8090737240075614
#
# =========================================
# =========================================
# largest value:  0.9996269
# smallest value:  1.132771e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.767
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	eval-auc:0.900571
#
# [[243  49]
#  [ 51 186]]
#
# 0.8109640831758034
#
# =========================================
# =========================================
# largest value:  0.99898475
# smallest value:  5.995696e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.767
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [21]	eval-auc:0.913286
# [[247  45]
#  [ 52 185]]
#
# 0.8166351606805293
#
# =========================================
# =========================================
# largest value:  0.9988218
# smallest value:  2.9664016e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.767
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	eval-auc:0.921857
#
# [[250  42]
#  [ 52 185]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.99907947
# smallest value:  3.44968e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.776143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	eval-auc:0.901571
#
# [[249  43]
#  [ 51 186]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.9991371
# smallest value:  2.1634316e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [19]	eval-auc:0.908571
#
# [[246  46]
#  [ 48 189]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.9987638
# smallest value:  2.220935e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	eval-auc:0.897143
#
# [[248  44]
#  [ 49 188]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.99802494
# smallest value:  2.2955383e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [31]	eval-auc:0.922714
#
# [[245  47]
#  [ 51 186]]
#
# 0.8147448015122873
#
# =========================================
# =========================================
# largest value:  0.9999087
# smallest value:  6.6107884e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773857
# Will train until eval-auc hasn't improved in 10 rounds.
# [50]	eval-auc:0.926429
# Stopping. Best iteration:
# [44]	eval-auc:0.931
#
# [[244  48]
#  [ 47 190]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.99993336
# smallest value:  3.047143e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	eval-auc:0.915571
#
# [[241  51]
#  [ 53 184]]
#
# 0.8034026465028355
#
# =========================================
# =========================================
# largest value:  0.9997712
# smallest value:  1.4745638e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.899429
#
# [[247  45]
#  [ 52 185]]
#
# 0.8166351606805293
#
# =========================================
# =========================================
# largest value:  0.9984755
# smallest value:  1.9042598e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [21]	eval-auc:0.902714
#
# [[246  46]
#  [ 48 189]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.9993075
# smallest value:  3.8921434e-07
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.773857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	eval-auc:0.909286
#
# [[247  45]
#  [ 48 189]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.9992861
# smallest value:  1.3218447e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.725857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	eval-auc:0.904286
#
# [[247  45]
#  [ 47 190]]
#
# 0.8260869565217391
#
# =========================================
# =========================================
# largest value:  0.9989409
# smallest value:  1.2129954e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.725857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [25]	eval-auc:0.910571
#
# [[247  45]
#  [ 50 187]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.99895823
# smallest value:  4.6977816e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.725857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	eval-auc:0.898857
#
# [[247  45]
#  [ 50 187]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.9979247
# smallest value:  3.4551944e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.725857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [29]	eval-auc:0.915143
#
# [[247  45]
#  [ 50 187]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.99952936
# smallest value:  4.43194e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.725857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [37]	eval-auc:0.914286
#
# [[243  49]
#  [ 50 187]]
#
# 0.8128544423440454
#
# =========================================
# =========================================
# largest value:  0.9996755
# smallest value:  1.6005915e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.703286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [22]	eval-auc:0.924
#
# [[246  46]
#  [ 49 188]]
#
# 0.8204158790170132
#
# =========================================
# =========================================
# largest value:  0.99943787
# smallest value:  6.1201276e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.703286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [26]	eval-auc:0.916143
#
# [[246  46]
#  [ 50 187]]
#
# 0.8185255198487713
#
# =========================================
# =========================================
# largest value:  0.99898344
# smallest value:  4.6348487e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.703286
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [28]	eval-auc:0.910571
#
# [[243  49]
#  [ 49 188]]
#
# 0.8147448015122873
#
# =========================================
# =========================================
# largest value:  0.99877816
# smallest value:  1.4330697e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.686429
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	eval-auc:0.893143
#
# [[243  49]
#  [ 49 188]]
#
# 0.8147448015122873
#
# =========================================
# =========================================
# largest value:  0.99851257
# smallest value:  5.9472563e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.694143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [20]	eval-auc:0.905
#
# [[243  49]
#  [ 48 189]]
#
# 0.8166351606805293
#
# =========================================
# =========================================
# largest value:  0.9997663
# smallest value:  1.8989732e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.694143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	eval-auc:0.907429
#
# [[246  46]
#  [ 48 189]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.99911815
# smallest value:  3.878374e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.694143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.892714
#
# [[243  49]
#  [ 50 187]]
#
# 0.8128544423440454
#
# =========================================
# =========================================
# largest value:  0.9988446
# smallest value:  3.013599e-07
# len of largest list:  14
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  34
# [0]	eval-auc:0.694143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [22]	eval-auc:0.912571
#
# [[243  49]
#  [ 50 187]]
#
# 0.8128544423440454
#
# =========================================
# =========================================
# largest value:  0.9140002
# smallest value:  5.258942e-07
# len of largest list:  10
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  30
# [0]	eval-auc:0.701857
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	eval-auc:0.910571
#
# [[245  47]
#  [ 47 190]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.9448265
# smallest value:  2.106235e-05
# len of largest list:  16
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  36
# [0]	eval-auc:0.717
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	eval-auc:0.907857
#
# [[242  50]
#  [ 46 191]]
#
# 0.8185255198487713
#
# =========================================
# =========================================
# largest value:  0.9626996
# smallest value:  7.2482144e-05
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.713
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [19]	eval-auc:0.906143
#
# [[244  48]
#  [ 46 191]]
#
# 0.8223062381852552
#
# =========================================
# =========================================
# largest value:  0.99335843
# smallest value:  7.6006468e-06
# len of largest list:  20
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  40
# [0]	eval-auc:0.728143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	eval-auc:0.910571
#
# [[245  47]
#  [ 46 191]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.98784685
# smallest value:  7.622436e-07
# len of largest list:  16
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  36
# [0]	eval-auc:0.728143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	eval-auc:0.917429
#
# [[245  47]
#  [ 46 191]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.92971855
# smallest value:  9.572617e-07
# len of largest list:  6
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  26
# [0]	eval-auc:0.728143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	eval-auc:0.916429
#
# [[245  47]
#  [ 46 191]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.6422954
# smallest value:  3.0549602e-06
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  20
# [0]	eval-auc:0.728143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	eval-auc:0.910714
#
# [[245  47]
#  [ 46 191]]
#
# 0.8241965973534972
#
# =========================================
# =========================================
# largest value:  0.8759537
# smallest value:  1.6673956e-06
# len of largest list:  1
# len of smallest list:  20
# =========================================
# =========================================
# number of newly added:  21
# [0]	eval-auc:0.728143
# Will train until eval-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	eval-auc:0.918857
#
# [[245  47]
#  [ 46 191]]
#
# 0.8241965973534972

# %%
from matplotlib import pyplot as plt
def drawLine(data):
    dataRange = [i for i in range(1,len(data)+1)]
    df = pd.DataFrame({'x':dataRange, 'y':data})
    plt.plot( 'x', 'y', data=df, marker='o', color='mediumvioletred')
    plt.show()

# %%
drawLine(accuracy)
# Out:
# /Users/heyuhao/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:3358: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   ret = ax.plot(*args, **kwargs)

# %%
#some techniques may need

# 1. concatenate 2 np array
# a=np.array([[1,2]])
# b=np.array([[1,2]])
# print(np.concatenate((a, b), axis=0)) -- print[[1,2],[1,2]]

# 2. table column unique value counts
# print(y_labeled.value_counts())

# 3. np array unique value counts
# unique, counts = np.unique(y_labeled, return_counts=True)
# print(np.asarray((unique, counts)).T)
